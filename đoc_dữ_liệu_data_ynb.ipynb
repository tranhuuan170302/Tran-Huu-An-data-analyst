# %% [markdown]
# <a href="https://colab.research.google.com/github/tranhuuan170302/Tran-Huu-An-data-analyst/blob/main/%C4%91oc_d%C6%B0%CC%83_li%C3%AA%CC%A3u_data_ynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df_ex = pd.read_excel("/content/drive/MyDrive/phân tích dữ liệu/pandas-1/data/data bai 1/FoodPrice_in_Turkey.xls")
df_ex.head()
# Out:
#    Unnamed: 0             Place  ProductId  ... Month  Year   Price
# 0           0  National Average         52  ...     5  2013  4.4920
# 1           1  National Average         52  ...     6  2013  4.5786
# 2           2  National Average         52  ...    11  2013  4.7865
# 3           3  National Average         52  ...    12  2013  5.1337
# 4           4  National Average         52  ...     1  2014  5.5099
#
# [5 rows x 9 columns]

# %% [markdown]
# # đọc file hdf

# %%
# !pip install --upgrade tables

# %%
df_hdf = pd.read_hdf("/content/drive/MyDrive/phân tích dữ liệu/pandas-1/data/data bai 1/FoodPrice_in_Turkey.hdf")
df_hdf.head()
# Out:
#               Place  ProductId    ProductName  UmId UmName  Month  Year   Price
# 0  National Average         52  Rice - Retail     5     KG      5  2013  4.4920
# 1  National Average         52  Rice - Retail     5     KG      6  2013  4.5786
# 2  National Average         52  Rice - Retail     5     KG     11  2013  4.7865
# 3  National Average         52  Rice - Retail     5     KG     12  2013  5.1337
# 4  National Average         52  Rice - Retail     5     KG      1  2014  5.5099

# %% [markdown]
# # đọc file json

# %%
df_js = pd.read_json("https://raw.githubusercontent.com/hainmit09/DataAnalysis/main/Bai_2_data/FoodPrice_in_Turkey.json")
df_js.head()
# Out:
#               Place  ProductId    ProductName  UmId UmName  Month  Year   Price
# 0  National Average         52  Rice - Retail     5     KG      5  2013  4.4920
# 1  National Average         52  Rice - Retail     5     KG      6  2013  4.5786
# 2  National Average         52  Rice - Retail     5     KG     11  2013  4.7865
# 3  National Average         52  Rice - Retail     5     KG     12  2013  5.1337
# 4  National Average         52  Rice - Retail     5     KG      1  2014  5.5099

# %% [markdown]
# # đọc file html

# %%
df_html = pd.read_html("https://raw.githubusercontent.com/hainmit09/DataAnalysis/main/Bai_2_data/FoodPrice_in_Turkey.html")
df_html[0].head()
# Out:
#    Unnamed: 0             Place  ProductId  ... Month  Year   Price
# 0           0  National Average         52  ...     5  2013  4.4920
# 1           1  National Average         52  ...     6  2013  4.5786
# 2           2  National Average         52  ...    11  2013  4.7865
# 3           3  National Average         52  ...    12  2013  5.1337
# 4           4  National Average         52  ...     1  2014  5.5099
#
# [5 rows x 9 columns]
